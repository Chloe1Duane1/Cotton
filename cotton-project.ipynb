# %%
import cv2
import os
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

def preprocess_image(img):
    # Converts to greyscale
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return gray_img

def extract_features(img):
    # texture extraction
    textures = cv2.HuMoments(cv2.moments(cv2.equalizeHist(img))).flatten()
    return textures

def resize_images(images, size=(128, 128)):
    resized_images = [cv2.resize(img, size) for img in images]
    return resized_images

def data_augmentation(images, num_rotations=4, flip=True):
    augmented_images = []
    for img in images:
        augmented_images.append(img)
        for _ in range(num_rotations):
            rotated_img = np.rot90(img, k=np.random.randint(1, 4))
            augmented_images.append(rotated_img)
            if flip:
                flipped_img = cv2.flip(rotated_img, np.random.randint(-1, 2))
                augmented_images.append(flipped_img)
    return augmented_images

# Healthy plant path
healthy_images_dir = "/kaggle/input/cotton-dataset/Dataset/healthy"

# Sick plant path
rotten_images_dir = "/kaggle/input/cotton-dataset/Dataset/curl_stage2+sooty"

# healthy image pre-processing
healthy_images = [cv2.imread(os.path.join(healthy_images_dir, filename), cv2.IMREAD_COLOR) for filename in os.listdir(healthy_images_dir)]
healthy_images = [preprocess_image(img) for img in healthy_images]
healthy_images = resize_images(healthy_images)
healthy_labels = ['Healthy'] * len(healthy_images)

# rotten images pre-processing
rotten_images = [cv2.imread(os.path.join(rotten_images_dir, filename), cv2.IMREAD_COLOR) for filename in os.listdir(rotten_images_dir)]
rotten_images = [preprocess_image(img) for img in rotten_images]
rotten_images = resize_images(rotten_images)
rotten_labels = ['Rotten'] * len(rotten_images)


augmented_healthy_images = data_augmentation(healthy_images)
augmented_rotten_images = data_augmentation(rotten_images)

# Combine healthy and rotten images
all_images = augmented_healthy_images + augmented_rotten_images
all_labels = ['Healthy'] * len(augmented_healthy_images) + ['Rotten'] * len(augmented_rotten_images)

# lists->np arrays
all_images = np.array(all_images)
all_labels = np.array(all_labels)

# feature extractions
all_features = np.array([extract_features(img) for img in all_images])

# Standardize features
scaler = StandardScaler()
all_features_scaled = scaler.fit_transform(all_features)

# RF training
clf = RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=2, random_state=42)
clf.fit(all_features_scaled, all_labels)

#image classification
def classify_images(image_folder):
    predictions = []
    for filename in os.listdir(image_folder):
        # read image,pre-process
        image = cv2.imread(os.path.join(image_folder, filename))
        img_preprocessed = preprocess_image(image)
        
        
        #image rezing, feature extraction, and scale
        resized_img = cv2.resize(img_preprocessed, (128, 128))
        img_features = extract_features(resized_img)
        scaled_features = scaler.transform([img_features])
        
        # class prediction
        prediction = clf.predict(scaled_features)[0]
        predictions.append((filename, prediction))
    return predictions

# Group the images by category
dataset_dir = "/kaggle/input/cotton-dataset/Dataset"
predicted_labels = []
true_labels = []
for category in os.listdir(dataset_dir):
    category_dir = os.path.join(dataset_dir, category)
    if os.path.isdir(category_dir):
        print(f"\n{category} Images Classification:")
        category_predictions = classify_images(category_dir)
        for filename, prediction in category_predictions:
            print(f"{filename}: {prediction}")
            predicted_labels.append(prediction)
            if category == 'healthy':
                true_labels.append('Healthy')
            else:
                true_labels.append('Rotten')

#f1 score of all png
f1 = f1_score(true_labels, predicted_labels, average='macro', zero_division=0)
print(f"\nOverall F1 Score: {f1}")
# Out:
# curl_stage1+sooty Images Classification:
# CS1_Sooty (27).png: Rotten
# CS1_Sooty (33).png: Healthy
# CS1_Sooty (4).png: Rotten
# CS1_Sooty (30).png: Rotten
# CS1_Sooty (19).png: Healthy
# CS1_Sooty (12).png: Healthy
# CS1_Sooty (1).jpg: Healthy
# CS1_Sooty (24).png: Rotten
# CS1_Sooty (4).jpg: Rotten
# CS1_Sooty (18).png: Rotten
# CS1_Sooty (8).png: Healthy
# CS1_Sooty (44).png: Rotten
# CS1_Sooty (13).png: Rotten
# CS1_Sooty (34).png: Healthy
# CS1_Sooty (23).png: Rotten
# CS1_Sooty (11).png: Rotten
# CS1_Sooty (32).png: Rotten
# CS1_Sooty (3).png: Rotten
# CS1_Sooty (43).png: Rotten
# CS1_Sooty (16).png: Rotten
# CS1_Sooty (7).png: Rotten
# CS1_Sooty (3).jpg: Healthy
# CS1_Sooty (40).png: Rotten
# CS1_Sooty (9).png: Healthy
# CS1_Sooty (35).png: Rotten
# CS1_Sooty (47).png: Rotten
# CS1_Sooty (2).jpg: Healthy
# CS1_Sooty (21).png: Healthy
# CS1_Sooty (10).png: Rotten
# CS1_Sooty (20).png: Rotten
# CS1_Sooty (46).png: Rotten
# CS1_Sooty (45).png: Rotten
# CS1_Sooty (29).png: Rotten
# CS1_Sooty (36).png: Rotten
# CS1_Sooty (39).png: Rotten
# CS1_Sooty (48).png: Rotten
# CS1_Sooty (50).png: Rotten
# CS1_Sooty (25).png: Rotten
# CS1_Sooty (1).jpeg: Rotten
# CS1_Sooty (51).png: Rotten
# CS1_Sooty (1).png: Healthy
# CS1_Sooty (14).png: Rotten
# CS1_Sooty (26).png: Rotten
# CS1_Sooty (17).png: Rotten
# CS1_Sooty (15).png: Rotten
# CS1_Sooty (22).png: Rotten
# CS1_Sooty (28).png: Rotten
# CS1_Sooty (37).png: Rotten
# CS1_Sooty (42).png: Rotten
# CS1_Sooty (6).png: Healthy
# CS1_Sooty (5).png: Rotten
# CS1_Sooty (41).png: Rotten
# CS1_Sooty (31).png: Rotten
# CS1_Sooty (38).png: Rotten
# CS1_Sooty (2).png: Rotten
# CS1_Sooty (49).png: Healthy
#
# curl_stage1 Images Classification:
# CS1 (23).png: Rotten
# CS1 (36).png: Healthy
# CS1 (38).png: Healthy
# CS1 (9).png: Healthy
# CS1 (39).png: Healthy
# CS1 (34).png: Healthy
# CS1 (7).png: Rotten
# CS1 (45).png: Healthy
# CS1 (14).png: Rotten
# CS1 (3).png: Healthy
# CS1 (10).png: Healthy
# CS1 (19).png: Healthy
# CS1 (25).png: Rotten
# CS1 (2).png: Rotten
# CS1 (22).png: Rotten
# CS1 (59).png: Rotten
# CS1 (24).png: Rotten
# CS1 (37).png: Healthy
# CS1 (48).png: Healthy
# CS1 (64).png: Healthy
# CS1 (69).png: Healthy
# CS1 (40).png: Healthy
# CS1 (6).png: Healthy
# CS1 (55).png: Rotten
# CS1 (30).png: Rotten
# CS1 (5).png: Rotten
# CS1 (27).png: Rotten
# CS1 (68).png: Healthy
# CS1 (61).png: Rotten
# CS1 (2).jpg: Healthy
# CS1 (44).png: Healthy
# CS1 (42).png: Healthy
# CS1 (13).png: Healthy
# CS1 (43).png: Healthy
# CS1 (16).png: Rotten
# CS1 (70).png: Rotten
# CS1 (32).png: Healthy
# CS1 (3).jpg: Healthy
# CS1 (31).png: Healthy
# CS1 (52).png: Rotten
# CS1 (35).png: Healthy
# CS1 (20).png: Rotten
# CS1 (65).png: Rotten
# CS1 (4).png: Healthy
# CS1 (49).png: Rotten
# CS1 (66).png: Healthy
# CS1 (26).png: Rotten
# CS1 (33).png: Healthy
# CS1 (50).png: Healthy
# CS1 (56).png: Healthy
# CS1 (62).png: Rotten
# CS1 (51).png: Healthy
# CS1 (63).png: Rotten
# CS1 (1).png: Healthy
# CS1 (58).png: Healthy
# CS1 (11).png: Rotten
# CS1 (21).png: Rotten
# CS1 (47).png: Healthy
# CS1 (46).png: Healthy
# CS1 (53).png: Healthy
# CS1 (54).png: Rotten
# CS1 (1).jpg: Healthy
# CS1 (28).png: Healthy
# CS1 (57).png: Healthy
# CS1 (60).png: Healthy
# CS1 (12).png: Healthy
# CS1 (67).png: Healthy
# CS1 (4).jpg: Healthy
# CS1 (15).png: Healthy
# CS1 (18).png: Rotten
# CS1 (29).png: Healthy
# CS1 (41).png: Healthy
# CS1 (17).png: Rotten
# CS1 (8).png: Healthy
#
# healthy Images Classification:
# healthy (49).png: Healthy
# healthy (18).png: Healthy
# healthy (87).png: Healthy
# healthy (61).png: Healthy
# healthy (7).png: Healthy
# healthy (134).png: Healthy
# healthy (108).png: Healthy
# healthy (85).png: Healthy
# healthy (140).png: Healthy
# healthy (64).png: Healthy
# healthy (66).png: Healthy
# healthy (60).png: Healthy
# healthy (12).png: Healthy
# healthy (129).png: Healthy
# healthy (120).png: Healthy
# healthy (94).png: Healthy
# healthy (73).png: Healthy
# healthy (139).png: Healthy
# healthy (28).png: Healthy
# healthy (112).png: Healthy
# healthy (70).png: Healthy
# healthy (132).png: Healthy
# healthy (72).png: Healthy
# healthy (37).png: Healthy
# healthy (131).png: Healthy
# healthy (68).png: Healthy
# healthy (13).png: Healthy
# healthy (142).png: Healthy
# healthy (126).png: Healthy
# healthy (113).png: Healthy
# healthy (15).png: Healthy
# healthy (106).png: Healthy
# healthy (74).png: Healthy
# healthy (90).png: Healthy
# healthy (98).png: Healthy
# healthy (6).png: Healthy
# healthy (136).png: Healthy
# healthy (11).png: Healthy
# healthy (22).png: Healthy
# healthy (31).png: Healthy
# healthy (30).png: Healthy
# healthy (144).png: Healthy
# healthy (10).png: Healthy
# healthy (88).png: Healthy
# healthy (3).png: Healthy
# healthy (46).png: Healthy
# healthy (34).png: Healthy
# healthy (138).png: Healthy
# healthy (40).png: Healthy
# healthy (54).png: Healthy
# healthy (29).png: Healthy
# healthy (124).png: Healthy
# healthy (1).png: Healthy
# healthy (39).png: Healthy
# healthy (4).png: Healthy
# healthy (57).png: Healthy
# healthy (127).png: Healthy
# healthy (119).png: Healthy
# healthy (32).png: Healthy
# healthy (111).png: Healthy
# healthy (104).png: Healthy
# healthy (92).png: Healthy
# healthy (55).png: Healthy
# healthy (109).png: Healthy
# healthy (75).png: Healthy
# healthy (25).png: Healthy
# healthy (130).png: Healthy
# healthy (99).png: Healthy
# healthy (105).png: Healthy
# healthy (56).png: Healthy
# healthy (103).png: Healthy
# healthy (128).png: Healthy
# healthy (89).png: Healthy
# healthy (23).png: Healthy
# healthy (141).png: Healthy
# healthy (27).png: Healthy
# healthy (95).png: Healthy
# healthy (5).png: Healthy
# healthy (24).png: Healthy
# healthy (50).png: Healthy
# healthy (9).png: Healthy
# healthy (122).png: Healthy
# healthy (44).png: Healthy
# healthy (8).png: Healthy
# healthy (83).png: Healthy
# healthy (79).png: Healthy
# healthy (121).png: Healthy
# healthy (2).png: Healthy
# healthy (110).png: Healthy
# healthy (123).png: Healthy
# healthy (36).png: Healthy
# healthy (67).png: Healthy
# healthy (125).png: Healthy
# healthy (78).png: Healthy
# healthy (58).png: Healthy
# healthy (116).png: Healthy
# healthy (137).png: Healthy
# healthy (71).png: Healthy
# healthy (91).png: Healthy
# healthy (107).png: Healthy
# healthy (41).png: Healthy
# healthy (43).png: Healthy
# healthy (45).png: Healthy
# healthy (84).png: Healthy
# healthy (100).png: Healthy
# healthy (86).png: Healthy
# healthy (135).png: Healthy
# healthy (47).png: Healthy
# healthy (38).png: Healthy
# healthy (51).png: Healthy
# healthy (14).png: Healthy
# healthy (96).png: Healthy
# healthy (17).png: Healthy
# healthy (117).png: Healthy
# healthy (76).png: Healthy
# healthy (63).png: Healthy
# healthy (19).png: Healthy
# healthy (133).png: Healthy
# healthy (26).png: Healthy
# healthy (97).png: Healthy
# healthy (59).png: Healthy
# healthy (62).png: Healthy
# healthy (65).png: Healthy
# healthy (114).png: Healthy
# healthy (77).png: Healthy
# healthy (80).png: Healthy
# healthy (48).png: Healthy
# healthy (69).png: Healthy
# healthy (20).png: Healthy
# healthy (82).png: Healthy
# healthy (33).png: Healthy
# healthy (101).png: Healthy
# healthy (102).png: Healthy
# healthy (93).png: Healthy
# healthy (115).png: Healthy
# healthy (35).png: Healthy
# healthy (53).png: Healthy
# healthy (21).png: Healthy
# healthy (52).png: Healthy
# healthy (118).png: Healthy
# healthy (16).png: Healthy
# healthy (81).png: Healthy
# healthy (143).png: Healthy
# healthy (42).png: Healthy
#
# curl_stage2+sooty Images Classification:
# CS2_sooty (28).png: Rotten
# CS2_sooty (26).png: Rotten
# CS2_sooty (7).png: Rotten
# CS2_sooty (29).png: Rotten
# CS2_sooty (39).png: Rotten
# CS2_sooty (1).jpeg: Rotten
# CS2_sooty (49).png: Rotten
# CS2_sooty (25).png: Rotten
# CS2_sooty (27).png: Rotten
# CS2_sooty (19).png: Rotten
# CS2_sooty (40).png: Rotten
# CS2_sooty (71).png: Rotten
# CS2_sooty (14).png: Rotten
# CS2_sooty (23).png: Rotten
# CS2_sooty (5).png: Rotten
# CS2_sooty (24).png: Rotten
# CS2_sooty (3).png: Rotten
# CS2_sooty (77).png: Rotten
# CS2_sooty (85).png: Rotten
# CS2_sooty (72).png: Rotten
# CS2_sooty (69).png: Rotten
# CS2_sooty (15).png: Rotten
# CS2_sooty (86).png: Rotten
# CS2_sooty (36).png: Rotten
# CS2_sooty (66).png: Rotten
# CS2_sooty (46).png: Rotten
# CS2_sooty (70).png: Rotten
# CS2_sooty (48).png: Rotten
# CS2_sooty (37).png: Rotten
# CS2_sooty (42).png: Rotten
# CS2_sooty (78).png: Rotten
# CS2_sooty (38).png: Rotten
# CS2_sooty (6).png: Rotten
# CS2_sooty (63).png: Rotten
# CS2_sooty (55).png: Rotten
# CS2_sooty (90).png: Rotten
# CS2_sooty (82).png: Rotten
# CS2_sooty (76).png: Rotten
# CS2_sooty (16).png: Rotten
# CS2_sooty (61).png: Rotten
# CS2_sooty (87).png: Rotten
# CS2_sooty (43).png: Rotten
# CS2_sooty (68).png: Rotten
# CS2_sooty (79).png: Rotten
# CS2_sooty (45).png: Rotten
# CS2_sooty (9).png: Rotten
# CS2_sooty (56).png: Rotten
# CS2_sooty (30).png: Rotten
# CS2_sooty (20).png: Rotten
# CS2_sooty (59).png: Rotten
# CS2_sooty (1).png: Rotten
# CS2_sooty (2).png: Rotten
# CS2_sooty (80).png: Rotten
# CS2_sooty (44).png: Rotten
# CS2_sooty (13).png: Rotten
# CS2_sooty (50).png: Rotten
# CS2_sooty (41).png: Rotten
# CS2_sooty (17).png: Rotten
# CS2_sooty (65).png: Rotten
# CS2_sooty (54).png: Rotten
# CS2_sooty (52).png: Rotten
# CS2_sooty (22).png: Rotten
# CS2_sooty (81).png: Rotten
# CS2_sooty (11).png: Rotten
# CS2_sooty (32).png: Rotten
# CS2_sooty (21).png: Rotten
# CS2_sooty (58).png: Rotten
# CS2_sooty (2).jpeg: Rotten
# CS2_sooty (33).png: Rotten
# CS2_sooty (73).png: Rotten
# CS2_sooty (53).png: Rotten
# CS2_sooty (74).png: Rotten
# CS2_sooty (84).png: Rotten
# CS2_sooty (83).png: Rotten
# CS2_sooty (10).png: Rotten
# CS2_sooty (31).png: Rotten
# CS2_sooty (51).png: Rotten
# CS2_sooty (12).png: Rotten
# CS2_sooty (34).png: Rotten
# CS2_sooty (18).png: Rotten
# CS2_sooty (89).png: Rotten
# CS2_sooty (88).png: Rotten
# CS2_sooty (57).png: Rotten
# CS2_sooty (75).png: Rotten
# CS2_sooty (8).png: Rotten
# CS2_sooty (4).png: Rotten
# CS2_sooty (47).png: Rotten
# CS2_sooty (35).png: Rotten
# CS2_sooty (62).png: Rotten
# CS2_sooty (67).png: Rotten
# CS2_sooty (64).png: Rotten
# CS2_sooty (60).png: Rotten
#
# curl_stage1+curl_stage2+sooty Images Classification:
# CS1_2_sooty (13).png: Rotten
# CS1_2_sooty (18).png: Healthy
# CS1_2_sooty (15).png: Rotten
# CS1_2_sooty (9).png: Rotten
# CS1_2_sooty (1).jpg: Healthy
# CS1_2_sooty (19).png: Rotten
# CS1_2_sooty (20).png: Healthy
# CS1_2_sooty (4).png: Rotten
# CS1_2_sooty (17).png: Rotten
# CS1_2_sooty (3).png: Rotten
# CS1_2_sooty (22).png: Rotten
# CS1_2_sooty (2).png: Rotten
# CS1_2_sooty (12).png: Rotten
# CS1_2_sooty (11).png: Healthy
# CS1_2_sooty (10).png: Rotten
# CS1_2_sooty (6).png: Rotten
# CS1_2_sooty (7).png: Rotten
# CS1_2_sooty (16).png: Rotten
# CS1_2_sooty (14).png: Rotten
# CS1_2_sooty (21).png: Rotten
# CS1_2_sooty (1).png: Rotten
# CS1_2_sooty (5).png: Healthy
# CS1_2_sooty (8).png: Rotten
#
# curl_stage2 Images Classification:
# CS2 (59).png: Rotten
# CS2 (58).png: Healthy
# CS2 (7).png: Rotten
# CS2 (25).png: Rotten
# CS2 (47).png: Healthy
# CS2 (2).jpg: Healthy
# CS2 (38).png: Rotten
# CS2 (57).png: Rotten
# CS2 (26).png: Rotten
# CS2 (3).jpg: Healthy
# CS2 (36).png: Rotten
# CS2 (53).png: Healthy
# CS2 (33).png: Healthy
# CS2 (15).png: Rotten
# CS2 (63).png: Healthy
# CS2 (3).jpeg: Healthy
# CS2 (24).png: Rotten
# CS2 (14).png: Healthy
# CS2 (22).png: Healthy
# CS2 (1).jpeg: Healthy
# CS2 (23).png: Rotten
# CS2 (7).jpeg: Healthy
# CS2 (32).png: Rotten
# CS2 (11).png: Rotten
# CS2 (48).png: Rotten
# CS2 (16).png: Healthy
# CS2 (8).png: Healthy
# CS2 (4).png: Healthy
# CS2 (46).png: Rotten
# CS2 (52).png: Healthy
# CS2 (5).png: Healthy
# CS2 (2).png: Rotten
# CS2 (56).png: Rotten
# CS2 (3).png: Healthy
# CS2 (43).png: Rotten
# CS2 (8).jpeg: Rotten
# CS2 (1).png: Rotten
# CS2 (6).jpg: Healthy
# CS2 (42).png: Healthy
# CS2 (40).png: Rotten
# CS2 (17).png: Rotten
# CS2 (21).png: Rotten
# CS2 (51).png: Rotten
# CS2 (44).png: Rotten
# CS2 (45).png: Rotten
# CS2 (4).jpg: Healthy
# CS2 (64).png: Rotten
# CS2 (27).png: Rotten
# CS2 (20).png: Healthy
# CS2 (49).png: Healthy
# CS2 (34).png: Healthy
# CS2 (5).jpg: Healthy
# CS2 (6).jpeg: Rotten
# CS2 (55).png: Rotten
# CS2 (13).png: Rotten
# CS2 (4).jpeg: Healthy
# CS2 (19).png: Rotten
# CS2 (39).png: Rotten
# CS2 (41).png: Rotten
# CS2 (12).png: Rotten
# CS2 (60).png: Rotten
# CS2 (37).png: Rotten
# CS2 (5).jpeg: Healthy
# CS2 (31).png: Healthy
# CS2 (54).png: Healthy
# CS2 (30).png: Rotten
# CS2 (6).png: Rotten
# CS2 (9).png: Rotten
# CS2 (18).png: Rotten
# CS2 (61).png: Rotten
# CS2 (29).png: Healthy
# CS2 (28).png: Rotten
# CS2 (35).png: Rotten
# CS2 (2).jpeg: Rotten
# CS2 (1).jpg: Healthy
# CS2 (62).png: Rotten
# CS2 (65).png: Healthy
# CS2 (50).png: Healthy
# CS2 (7).jpg: Rotten
# CS2 (10).png: Rotten
#
# Overall F1 Score: 0.7842888788766238
